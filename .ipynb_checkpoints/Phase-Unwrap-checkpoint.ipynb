# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

for i in range(1,76):
    
    img = np.genfromtxt('./processed/processed/phase_data_la4ch1/x/' + str(i) + '.txt',np.float32)

    print(img.shape)
    #plt.imshow(img,cmap='')
    plt.imsave(str(i)+'.jpg',img,cmap='gray')
    #plt.show()
# Out:
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)
# (192, 192)

# %%
# !python test.py
# Out:
# img shape =  (192, 192, 3)
# num_white_px =  485
# num_black_px =  246
# white_to_black_ratio =  1.9715447154471544
# RoI_is_white True
# [(100.0, 68.0), (100.0, 69.0), (101.0, 69.0), (94.0, 70.0), (100.0, 70.0), (101.0, 70.0), (102.0, 70.0), (94.0, 71.0), (100.0, 71.0), (101.0, 71.0), (102.0, 71.0), (103.0, 71.0), (104.0, 71.0), (94.0, 72.0), (95.0, 72.0), (100.0, 72.0), (101.0, 72.0), (102.0, 72.0), (103.0, 72.0), (104.0, 72.0), (105.0, 72.0), (106.0, 72.0), (107.0, 72.0), (94.0, 73.0), (95.0, 73.0), (99.0, 73.0), (100.0, 73.0), (101.0, 73.0), (102.0, 73.0), (103.0, 73.0), (104.0, 73.0), (105.0, 73.0), (106.0, 73.0), (107.0, 73.0), (108.0, 73.0), (109.0, 73.0), (110.0, 73.0), (111.0, 73.0), (94.0, 74.0), (95.0, 74.0), (99.0, 74.0), (100.0, 74.0), (101.0, 74.0), (102.0, 74.0), (103.0, 74.0), (104.0, 74.0), (105.0, 74.0), (106.0, 74.0), (107.0, 74.0), (108.0, 74.0), (109.0, 74.0), (110.0, 74.0), (111.0, 74.0), (112.0, 74.0), (94.0, 75.0), (99.0, 75.0), (100.0, 75.0), (101.0, 75.0), (102.0, 75.0), (103.0, 75.0), (104.0, 75.0), (105.0, 75.0), (106.0, 75.0), (107.0, 75.0), (108.0, 75.0), (109.0, 75.0), (110.0, 75.0), (111.0, 75.0), (112.0, 75.0), (94.0, 76.0), (95.0, 76.0), (99.0, 76.0), (100.0, 76.0), (101.0, 76.0), (102.0, 76.0), (103.0, 76.0), (104.0, 76.0), (105.0, 76.0), (106.0, 76.0), (107.0, 76.0), (108.0, 76.0), (109.0, 76.0), (110.0, 76.0), (111.0, 76.0), (112.0, 76.0), (113.0, 76.0), (94.0, 77.0), (95.0, 77.0), (99.0, 77.0), (100.0, 77.0), (101.0, 77.0), (102.0, 77.0), (103.0, 77.0), (104.0, 77.0), (105.0, 77.0), (106.0, 77.0), (107.0, 77.0), (108.0, 77.0), (109.0, 77.0), (110.0, 77.0), (111.0, 77.0), (112.0, 77.0), (113.0, 77.0), (94.0, 78.0), (95.0, 78.0), (98.0, 78.0), (99.0, 78.0), (100.0, 78.0), (101.0, 78.0), (102.0, 78.0), (103.0, 78.0), (104.0, 78.0), (105.0, 78.0), (106.0, 78.0), (107.0, 78.0), (108.0, 78.0), (109.0, 78.0), (110.0, 78.0), (111.0, 78.0), (112.0, 78.0), (113.0, 78.0), (94.0, 79.0), (98.0, 79.0), (99.0, 79.0), (100.0, 79.0), (101.0, 79.0), (102.0, 79.0), (103.0, 79.0), (104.0, 79.0), (105.0, 79.0), (106.0, 79.0), (107.0, 79.0), (108.0, 79.0), (109.0, 79.0), (110.0, 79.0), (111.0, 79.0), (112.0, 79.0), (113.0, 79.0), (94.0, 80.0), (98.0, 80.0), (99.0, 80.0), (100.0, 80.0), (101.0, 80.0), (102.0, 80.0), (103.0, 80.0), (104.0, 80.0), (105.0, 80.0), (106.0, 80.0), (107.0, 80.0), (108.0, 80.0), (109.0, 80.0), (110.0, 80.0), (111.0, 80.0), (112.0, 80.0), (113.0, 80.0), (94.0, 81.0), (98.0, 81.0), (99.0, 81.0), (100.0, 81.0), (101.0, 81.0), (102.0, 81.0), (103.0, 81.0), (104.0, 81.0), (105.0, 81.0), (106.0, 81.0), (107.0, 81.0), (108.0, 81.0), (109.0, 81.0), (110.0, 81.0), (111.0, 81.0), (112.0, 81.0), (113.0, 81.0), (94.0, 82.0), (99.0, 82.0), (100.0, 82.0), (101.0, 82.0), (102.0, 82.0), (103.0, 82.0), (104.0, 82.0), (105.0, 82.0), (106.0, 82.0), (107.0, 82.0), (108.0, 82.0), (109.0, 82.0), (110.0, 82.0), (111.0, 82.0), (112.0, 82.0), (113.0, 82.0), (99.0, 83.0), (100.0, 83.0), (101.0, 83.0), (102.0, 83.0), (103.0, 83.0), (104.0, 83.0), (105.0, 83.0), (106.0, 83.0), (107.0, 83.0), (108.0, 83.0), (109.0, 83.0), (110.0, 83.0), (111.0, 83.0), (112.0, 83.0), (113.0, 83.0), (99.0, 84.0), (100.0, 84.0), (101.0, 84.0), (102.0, 84.0), (103.0, 84.0), (104.0, 84.0), (105.0, 84.0), (106.0, 84.0), (107.0, 84.0), (108.0, 84.0), (109.0, 84.0), (110.0, 84.0), (111.0, 84.0), (112.0, 84.0), (113.0, 84.0), (100.0, 85.0), (101.0, 85.0), (102.0, 85.0), (103.0, 85.0), (104.0, 85.0), (105.0, 85.0), (106.0, 85.0), (107.0, 85.0), (108.0, 85.0), (109.0, 85.0), (110.0, 85.0), (111.0, 85.0), (112.0, 85.0), (113.0, 85.0), (100.0, 86.0), (101.0, 86.0), (102.0, 86.0), (103.0, 86.0), (104.0, 86.0), (105.0, 86.0), (106.0, 86.0), (107.0, 86.0), (108.0, 86.0), (109.0, 86.0), (110.0, 86.0), (111.0, 86.0), (112.0, 86.0), (100.0, 87.0), (101.0, 87.0), (102.0, 87.0), (103.0, 87.0), (104.0, 87.0), (105.0, 87.0), (106.0, 87.0), (107.0, 87.0), (108.0, 87.0), (109.0, 87.0), (110.0, 87.0), (111.0, 87.0), (112.0, 87.0), (101.0, 88.0), (102.0, 88.0), (103.0, 88.0), (104.0, 88.0), (105.0, 88.0), (106.0, 88.0), (107.0, 88.0), (108.0, 88.0), (109.0, 88.0), (108.0, 89.0)]
# [(94.0, 53.0), (95.0, 53.0), (96.0, 53.0), (97.0, 53.0), (98.0, 53.0), (99.0, 53.0), (100.0, 53.0), (101.0, 53.0), (102.0, 53.0), (103.0, 53.0), (104.0, 53.0), (105.0, 53.0), (106.0, 53.0), (107.0, 53.0), (108.0, 53.0), (109.0, 53.0), (110.0, 53.0), (111.0, 53.0), (112.0, 53.0), (113.0, 53.0), (114.0, 53.0), (94.0, 54.0), (95.0, 54.0), (96.0, 54.0), (97.0, 54.0), (98.0, 54.0), (99.0, 54.0), (100.0, 54.0), (101.0, 54.0), (102.0, 54.0), (103.0, 54.0), (104.0, 54.0), (105.0, 54.0), (106.0, 54.0), (107.0, 54.0), (108.0, 54.0), (109.0, 54.0), (110.0, 54.0), (111.0, 54.0), (112.0, 54.0), (113.0, 54.0), (114.0, 54.0), (94.0, 55.0), (95.0, 55.0), (96.0, 55.0), (97.0, 55.0), (98.0, 55.0), (99.0, 55.0), (100.0, 55.0), (101.0, 55.0), (102.0, 55.0), (103.0, 55.0), (104.0, 55.0), (105.0, 55.0), (106.0, 55.0), (107.0, 55.0), (108.0, 55.0), (109.0, 55.0), (110.0, 55.0), (111.0, 55.0), (112.0, 55.0), (113.0, 55.0), (114.0, 55.0), (94.0, 56.0), (95.0, 56.0), (96.0, 56.0), (97.0, 56.0), (98.0, 56.0), (99.0, 56.0), (100.0, 56.0), (101.0, 56.0), (102.0, 56.0), (103.0, 56.0), (104.0, 56.0), (105.0, 56.0), (106.0, 56.0), (107.0, 56.0), (108.0, 56.0), (109.0, 56.0), (110.0, 56.0), (111.0, 56.0), (112.0, 56.0), (113.0, 56.0), (114.0, 56.0), (94.0, 57.0), (95.0, 57.0), (96.0, 57.0), (97.0, 57.0), (98.0, 57.0), (99.0, 57.0), (100.0, 57.0), (101.0, 57.0), (102.0, 57.0), (103.0, 57.0), (104.0, 57.0), (105.0, 57.0), (106.0, 57.0), (107.0, 57.0), (108.0, 57.0), (109.0, 57.0), (110.0, 57.0), (111.0, 57.0), (112.0, 57.0), (113.0, 57.0), (114.0, 57.0), (94.0, 58.0), (95.0, 58.0), (96.0, 58.0), (97.0, 58.0), (98.0, 58.0), (99.0, 58.0), (100.0, 58.0), (101.0, 58.0), (102.0, 58.0), (103.0, 58.0), (104.0, 58.0), (105.0, 58.0), (106.0, 58.0), (107.0, 58.0), (108.0, 58.0), (109.0, 58.0), (110.0, 58.0), (111.0, 58.0), (112.0, 58.0), (113.0, 58.0), (114.0, 58.0), (94.0, 59.0), (95.0, 59.0), (96.0, 59.0), (97.0, 59.0), (98.0, 59.0), (99.0, 59.0), (100.0, 59.0), (101.0, 59.0), (102.0, 59.0), (103.0, 59.0), (104.0, 59.0), (105.0, 59.0), (106.0, 59.0), (107.0, 59.0), (108.0, 59.0), (109.0, 59.0), (110.0, 59.0), (111.0, 59.0), (112.0, 59.0), (113.0, 59.0), (114.0, 59.0), (94.0, 60.0), (95.0, 60.0), (96.0, 60.0), (97.0, 60.0), (98.0, 60.0), (99.0, 60.0), (100.0, 60.0), (101.0, 60.0), (102.0, 60.0), (103.0, 60.0), (104.0, 60.0), (105.0, 60.0), (106.0, 60.0), (107.0, 60.0), (108.0, 60.0), (109.0, 60.0), (110.0, 60.0), (111.0, 60.0), (112.0, 60.0), (113.0, 60.0), (114.0, 60.0), (94.0, 61.0), (95.0, 61.0), (96.0, 61.0), (97.0, 61.0), (98.0, 61.0), (99.0, 61.0), (100.0, 61.0), (101.0, 61.0), (102.0, 61.0), (103.0, 61.0), (104.0, 61.0), (105.0, 61.0), (106.0, 61.0), (107.0, 61.0), (108.0, 61.0), (109.0, 61.0), (110.0, 61.0), (111.0, 61.0), (112.0, 61.0), (113.0, 61.0), (114.0, 61.0), (94.0, 62.0), (95.0, 62.0), (96.0, 62.0), (97.0, 62.0), (98.0, 62.0), (99.0, 62.0), (100.0, 62.0), (101.0, 62.0), (102.0, 62.0), (103.0, 62.0), (104.0, 62.0), (105.0, 62.0), (106.0, 62.0), (107.0, 62.0), (108.0, 62.0), (109.0, 62.0), (110.0, 62.0), (111.0, 62.0), (112.0, 62.0), (113.0, 62.0), (114.0, 62.0), (94.0, 63.0), (95.0, 63.0), (96.0, 63.0), (97.0, 63.0), (98.0, 63.0), (99.0, 63.0), (100.0, 63.0), (101.0, 63.0), (102.0, 63.0), (103.0, 63.0), (104.0, 63.0), (105.0, 63.0), (106.0, 63.0), (107.0, 63.0), (108.0, 63.0), (109.0, 63.0), (110.0, 63.0), (111.0, 63.0), (112.0, 63.0), (113.0, 63.0), (114.0, 63.0), (94.0, 64.0), (95.0, 64.0), (96.0, 64.0), (97.0, 64.0), (98.0, 64.0), (99.0, 64.0), (100.0, 64.0), (101.0, 64.0), (102.0, 64.0), (103.0, 64.0), (104.0, 64.0), (105.0, 64.0), (106.0, 64.0), (107.0, 64.0), (108.0, 64.0), (109.0, 64.0), (110.0, 64.0), (111.0, 64.0), (112.0, 64.0), (113.0, 64.0), (114.0, 64.0), (94.0, 65.0), (95.0, 65.0), (96.0, 65.0), (97.0, 65.0), (98.0, 65.0), (99.0, 65.0), (100.0, 65.0), (101.0, 65.0), (102.0, 65.0), (103.0, 65.0), (104.0, 65.0), (105.0, 65.0), (106.0, 65.0), (107.0, 65.0), (108.0, 65.0), (109.0, 65.0), (110.0, 65.0), (111.0, 65.0), (112.0, 65.0), (113.0, 65.0 ...
# ....length.... 268
# grid_x,grid_y 99.0 67.0
# delta -3
# grid_x,grid_y 99.0 68.0
# delta -9
# grid_x,grid_y 100.0 68.0
# delta -11
# grid_x,grid_y 93.0 69.0
# delta 1
# grid_x,grid_y 99.0 69.0
# delta -13
# grid_x,grid_y 100.0 69.0
# delta -17
# grid_x,grid_y 101.0 69.0
# delta -13
# grid_x,grid_y 93.0 70.0
# delta -3
# grid_x,grid_y 99.0 70.0
# delta -17
# grid_x,grid_y 100.0 70.0
# delta -21
# grid_x,grid_y 101.0 70.0
# delta -19
# grid_x,grid_y 102.0 70.0
# delta -15
# grid_x,grid_y 103.0 70.0
# delta -11
# grid_x,grid_y 93.0 71.0
# delta -5
# grid_x,grid_y 94.0 71.0
# delta -5
# grid_x,grid_y 99.0 71.0
# delta -19
# grid_x,grid_y 100.0 71.0
# delta -23
# grid_x,grid_y 101.0 71.0
# delta -23
# grid_x,grid_y 102.0 71.0
# delta -21
# grid_x,grid_y 103.0 71.0
# delta -19
# grid_x,grid_y 104.0 71.0
# delta -17
# grid_x,grid_y 105.0 71.0
# delta -13
# grid_x,grid_y 106.0 71.0
# delta -11
# grid_x,grid_y 93.0 72.0
# delta -5
# grid_x,grid_y 94.0 72.0
# delta -5
# grid_x,grid_y 98.0 72.0
# delta -13
# grid_x,grid_y 99.0 72.0
# delta -21
# grid_x,grid_y 100.0 72.0
# delta -23
# grid_x,grid_y 101.0 72.0
# delta -23
# grid_x,grid_y 102.0 72.0
# delta -23
# grid_x,grid_y 103.0 72.0
# delta -23
# grid_x,grid_y 104.0 72.0
# delta -23
# grid_x,grid_y 105.0 72.0
# delta -21
# grid_x,grid_y 106.0 72.0
# delta -19
# grid_x,grid_y 107.0 72.0
# delta -17
# grid_x,grid_y 108.0 72.0
# delta -15
# grid_x,grid_y 109.0 72.0
# delta -13
# grid_x,grid_y 110.0 72.0
# delta -7
# grid_x,grid_y 93.0 73.0
# delta -5
# grid_x,grid_y 94.0 73.0
# delta -5
# grid_x,grid_y 98.0 73.0
# delta -15
# grid_x,grid_y 99.0 73.0
# delta -23
# grid_x,grid_y 100.0 73.0
# delta -23
# grid_x,grid_y 101.0 73.0
# delta -23
# grid_x,grid_y 102.0 73.0
# delta -23
# grid_x,grid_y 103.0 73.0
# delta -23
# grid_x,grid_y 104.0 73.0
# delta -23
# grid_x,grid_y 105.0 73.0
# delta -23
# grid_x,grid_y 106.0 73.0
# delta -23
# grid_x,grid_y 107.0 73.0
# delta -23
# grid_x,grid_y 108.0 73.0
# delta -23
# grid_x,grid_y 109.0 73.0
# delta -21
# grid_x,grid_y 110.0 73.0
# delta -15
# grid_x,grid_y 111.0 73.0
# delta -7
# grid_x,grid_y 93.0 74.0
# delta -5
# grid_x,grid_y 98.0 74.0
# delta -15
# grid_x,grid_y 99.0 74.0
# delta -23
# grid_x,grid_y 100.0 74.0
# delta -23
# grid_x,grid_y 101.0 74.0
# delta -23
# grid_x,grid_y 102.0 74.0
# delta -23
# grid_x,grid_y 103.0 74.0
# delta -23
# grid_x,grid_y 104.0 74.0
# delta -23
# grid_x,grid_y 105.0 74.0
# delta -23
# grid_x,grid_y 106.0 74.0
# delta -23
# grid_x,grid_y 107.0 74.0
# delta -23
# grid_x,grid_y 108.0 74.0
# delta -23
# grid_x,grid_y 109.0 74.0
# delta -23
# grid_x,grid_y 110.0 74.0
# delta -19
# grid_x,grid_y 111.0 74.0
# delta -11
# grid_x,grid_y 93.0 75.0
# delta -5
# grid_x,grid_y 94.0 75.0
# delta -5
# grid_x,grid_y 98.0 75.0
# delta -17
# grid_x,grid_y 99.0 75.0
# delta -23
# grid_x,grid_y 100.0 75.0
# delta -23
# grid_x,grid_y 101.0 75.0
# delta -23
# grid_x,grid_y 102.0 75.0
# delta -23
# grid_x,grid_y 103.0 75.0
# delta -23
# grid_x,grid_y 104.0 75.0
# delta -23
# grid_x,grid_y 105.0 75.0
# delta -23
# grid_x,grid_y 106.0 75.0
# delta -23
# grid_x,grid_y 107.0 75.0
# delta -23
# grid_x,grid_y 108.0 75.0
# delta -23
# grid_x,grid_y 109.0 75.0
# delta -23
# grid_x,grid_y 110.0 75.0
# delta -21
# grid_x,grid_y 111.0 75.0
# delta -13
# grid_x,grid_y 112.0 75.0
# delta -5
# grid_x,grid_y 93.0 76.0
# delta -5
# grid_x,grid_y 94.0 76.0
# delta -5
# grid_x,grid_y 98.0 76.0
# delta -19
# grid_x,grid_y 99.0 76.0
# delta -23
# grid_x,grid_y 100.0 76.0
# delta -23
# grid_x,grid_y 101.0 76.0
# delta -23
# grid_x,grid_y 102.0 76.0
# delta -23
# grid_x,grid_y 103.0 76.0
# delta -23
# grid_x,grid_y 104.0 76.0
# delta -23
# grid_x,grid_y 105.0 76.0
# delta -23
# grid_x,grid_y 106.0 76.0
# delta -23
# grid_x,grid_y 107.0 76.0
# delta -23
# grid_x,grid_y 108.0 76.0
# delta -23
# grid_x,grid_y 109.0 76.0
# delta -23
# grid_x,grid_y 110.0 76.0
# delta -23
# grid_x,grid_y 111.0 76.0
# delta -15
# grid_x,grid_y 112.0 76.0
# delta -7
# grid_x,grid_y 93.0 77.0
# delta -3
# grid_x,grid_y 94.0 77.0
# delta -3
# grid_x,grid_y 97.0 77.0
# delta -13
# grid_x,grid_y 98.0 77.0
# delta -21
# grid_x,grid_y 99.0 77.0
# delta -23
# grid_x,grid_y 100.0 77.0
# delta -23
# grid_x,grid_y 101.0 77.0
# delta -23
# grid_x,grid_y 102.0 77.0
# delta -23
# grid_x,grid_y 103.0 77.0
# delta -23
# grid_x,grid_y 104.0 77.0
# delta -23
# grid_x,grid_y 105.0 77.0
# delta -23
# grid_x,grid_y 106.0 77.0
# delta -23
# grid_x,grid_y 107.0 77.0
# delta -23
# grid_x,grid_y 108.0 77.0
# delta -23
# grid_x,grid_y 109.0 77.0
# delta -23
# grid_x,grid_y 110.0 77.0
# delta -23
# grid_x,grid_y 111.0 77.0
# delta -15
# grid_x,grid_y 112.0 77.0
# delta -7
# grid_x,grid_y 93.0 78.0
# delta -1
# grid_x,grid_y 97.0 78.0
# delta -15
# grid_x,grid_y 98.0 78.0
# delta -23
# grid_x,grid_y 99.0 78.0
# delta -23
# grid_x,grid_y 100.0 78.0
# delta -23
# grid_x,grid_y 101.0 78.0
# delta -23
# grid_x,grid_y 102.0 78.0
# delta -23
# grid_x,grid_y 103.0 78.0
# delta -23
# grid_x,grid_y 104.0 78.0
# delta -23
# grid_x,grid_y 105.0 78.0
# delta -23
# grid_x,grid_y 106.0 78.0
# delta -23
# grid_x,grid_y 107.0 78.0
# delta -23
# grid_x,grid_y 108.0 78.0
# delta -23
# grid_x,grid_y 109.0 78.0
# delta -23
# grid_x,grid_y 110.0 78.0
# delta -23
# grid_x,grid_y 111.0 78.0
# delta -15
# grid_x,grid_y 112.0 78.0
# delta -7
# grid_x,grid_y 93.0 79.0
# delta 1
# grid_x,grid_y 97.0 79.0
# delta -13
# grid_x,grid_y 98.0 79.0
# delta -21
# grid_x,grid_y 99.0 79.0
# delta -23
# grid_x,grid_y 100.0 79.0
# delta -23
# grid_x,grid_y 101.0 79.0
# delta -23
# grid_x,grid_y 102.0 79.0
# delta -23
# grid_x,grid_y 103.0 79.0
# delta -23
# grid_x,grid_y 104.0 79.0
# delta -23
# grid_x,grid_y 105.0 79.0
# delta -23
# grid_x,grid_y 106.0 79.0
# delta -23
# grid_x,grid_y 107.0 79.0
# delta -23
# grid_x,grid_y 108.0 79.0
# delta -23
# grid_x,grid_y 109.0 79.0
# delta -23
# grid_x,grid_y 110.0 79.0
# delta -23
# grid_x,grid_y 111.0 79.0
# delta -15
# grid_x,grid_y 112.0 79.0
# delta -7
# grid_x,grid_y 93.0 80.0
# delta 3
# grid_x,grid_y 97.0 80.0
# delta -11
# grid_x,grid_y 98.0 80.0
# delta -19
# grid_x,grid_y 99.0 80.0
# delta -23
# grid_x,grid_y 100.0 80.0
# delta -23
# grid_x,grid_y 101.0 80.0
# delta -23
# grid_x,grid_y 102.0 80.0
# delta -23
# grid_x,grid_y 103.0 80.0
# delta -23
# grid_x,grid_y 104.0 80.0
# delta -23
# grid_x,grid_y 105.0 80.0
# delta -23
# grid_x,grid_y 106.0 80.0
# delta -23
# grid_x,grid_y 107.0 80.0
# delta -23
# grid_x,grid_y 108.0 80.0
# delta -23
# grid_x,grid_y 109.0 80.0
# delta -23
# grid_x,grid_y 110.0 80.0
# delta -23
# grid_x,grid_y 111.0 80.0
# delta -15
# grid_x,grid_y 112.0 80.0
# delta -7
# grid_x,grid_y 93.0 81.0
# delta 5
# grid_x,grid_y 98.0 81.0
# delta -17
# grid_x,grid_y 99.0 81.0
# delta -23
# grid_x,grid_y 100.0 81.0
# delta -23
# grid_x,grid_y 101.0 81.0
# delta -23
# grid_x,grid_y 102.0 81.0
# delta -23
# grid_x,grid_y 103.0 81.0
# delta -23
# grid_x,grid_y 104.0 81.0
# delta -23
# grid_x,grid_y 105.0 81.0
# delta -23
# grid_x,grid_y 106.0 81.0
# delta -23
# grid_x,grid_y 107.0 81.0
# delta -23
# grid_x,grid_y 108.0 81.0
# delta -23
# grid_x,grid_y 109.0 81.0
# delta -23
# grid_x,grid_y 110.0 81.0
# delta -23
# grid_x,grid_y 111.0 81.0
# delta -15
# grid_x,grid_y 112.0 81.0
# delta -7
# grid_x,grid_y 98.0 82.0
# delta -13
# grid_x,grid_y 99.0 82.0
# delta -21
# grid_x,grid_y 100.0 82.0
# delta -23
# grid_x,grid_y 101.0 82.0
# delta -23
# grid_x,grid_y 102.0 82.0
# delta -23
# grid_x,grid_y 103.0 82.0
# delta -23
# grid_x,grid_y 104.0 82.0
# delta -23
# grid_x,grid_y 105.0 82.0
# delta -23
# grid_x,grid_y 106.0 82.0
# delta -23
# grid_x,grid_y 107.0 82.0
# delta -23
# grid_x,grid_y 108.0 82.0
# delta -23
# grid_x,grid_y 109.0 82.0
# delta -23
# grid_x,grid_y 110.0 82.0
# delta -23
# grid_x,grid_y 111.0 82.0
# delta -15
# grid_x,grid_y 112.0 82.0
# delta -7
# grid_x,grid_y 98.0 83.0
# delta -11
# grid_x,grid_y 99.0 83.0
# delta -19
# grid_x,grid_y 100.0 83.0
# delta -23
# grid_x,grid_y 101.0 83.0
# delta -23
# grid_x,grid_y 102.0 83.0
# delta -23
# grid_x,grid_y 103.0 83.0
# delta -23
# grid_x,grid_y 104.0 83.0
# delta -23
# grid_x,grid_y 105.0 83.0
# delta -23
# grid_x,grid_y 106.0 83.0
# delta -23
# grid_x,grid_y 107.0 83.0
# delta -23
# grid_x,grid_y 108.0 83.0
# delta -23
# grid_x,grid_y 109.0 83.0
# delta -23
# grid_x,grid_y 110.0 83.0
# delta -21
# grid_x,grid_y 111.0 83.0
# delta -13
# grid_x,grid_y 112.0 83.0
# delta -5
# grid_x,grid_y 99.0 84.0
# delta -17
# grid_x,grid_y 100.0 84.0
# delta -23
# grid_x,grid_y 101.0 84.0
# delta -23
# grid_x,grid_y 102.0 84.0
# delta -23
# grid_x,grid_y 103.0 84.0
# delta -23
# grid_x,grid_y 104.0 84.0
# delta -23
# grid_x,grid_y 105.0 84.0
# delta -23
# grid_x,grid_y 106.0 84.0
# delta -23
# grid_x,grid_y 107.0 84.0
# delta -23
# grid_x,grid_y 108.0 84.0
# delta -23
# grid_x,grid_y 109.0 84.0
# delta -23
# grid_x,grid_y 110.0 84.0
# delta -19
# grid_x,grid_y 111.0 84.0
# delta -11
# grid_x,grid_y 112.0 84.0
# delta -3
# grid_x,grid_y 99.0 85.0
# delta -13
# grid_x,grid_y 100.0 85.0
# delta -21
# grid_x,grid_y 101.0 85.0
# delta -23
# grid_x,grid_y 102.0 85.0
# delta -23
# grid_x,grid_y 103.0 85.0
# delta -23
# grid_x,grid_y 104.0 85.0
# delta -23
# grid_x,grid_y 105.0 85.0
# delta -23
# grid_x,grid_y 106.0 85.0
# delta -23
# grid_x,grid_y 107.0 85.0
# delta -21
# grid_x,grid_y 108.0 85.0
# delta -19
# grid_x,grid_y 109.0 85.0
# delta -17
# grid_x,grid_y 110.0 85.0
# delta -11
# grid_x,grid_y 111.0 85.0
# delta -5
# grid_x,grid_y 99.0 86.0
# delta -7
# grid_x,grid_y 100.0 86.0
# delta -13
# grid_x,grid_y 101.0 86.0
# delta -15
# grid_x,grid_y 102.0 86.0
# delta -15
# grid_x,grid_y 103.0 86.0
# delta -15
# grid_x,grid_y 104.0 86.0
# delta -15
# grid_x,grid_y 105.0 86.0
# delta -17
# grid_x,grid_y 106.0 86.0
# delta -17
# grid_x,grid_y 107.0 86.0
# delta -15
# grid_x,grid_y 108.0 86.0
# delta -13
# grid_x,grid_y 109.0 86.0
# delta -9
# grid_x,grid_y 110.0 86.0
# delta -3
# grid_x,grid_y 111.0 86.0
# delta 1
# grid_x,grid_y 100.0 87.0
# delta -5
# grid_x,grid_y 101.0 87.0
# delta -7
# grid_x,grid_y 102.0 87.0
# delta -7
# grid_x,grid_y 103.0 87.0
# delta -7
# grid_x,grid_y 104.0 87.0
# delta -7
# grid_x,grid_y 105.0 87.0
# delta -9
# grid_x,grid_y 106.0 87.0
# delta -9
# grid_x,grid_y 107.0 87.0
# delta -7
# grid_x,grid_y 108.0 87.0
# delta -5
# grid_x,grid_y 107.0 88.0
# delta 1
# [((94.0, 82.0), 5), ((94.0, 81.0), 3), ((108.0, 89.0), 1), ((112.0, 87.0), 1), ((94.0, 80.0), 1), ((94.0, 70.0), 1), ((94.0, 79.0), -1), ((111.0, 87.0), -3), ((113.0, 85.0), -3), ((95.0, 78.0), -3), ((94.0, 78.0), -3), ((94.0, 71.0), -3), ((100.0, 68.0), -3), ((109.0, 88.0), -5), ((101.0, 88.0), -5), ((112.0, 86.0), -5), ((113.0, 84.0), -5), ((95.0, 77.0), -5), ((94.0, 77.0), -5), ((113.0, 76.0), -5), ((95.0, 76.0), -5), ((94.0, 76.0), -5), ((94.0, 75.0), -5), ((95.0, 74.0), -5), ((94.0, 74.0), -5), ((95.0, 73.0), -5), ((94.0, 73.0), -5), ((95.0, 72.0), -5), ((94.0, 72.0), -5), ((108.0, 88.0), -7), ((105.0, 88.0), -7), ((104.0, 88.0), -7), ((103.0, 88.0), -7), ((102.0, 88.0), -7), ((100.0, 87.0), -7), ((113.0, 83.0), -7), ((113.0, 82.0), -7), ((113.0, 81.0), -7), ((113.0, 80.0), -7), ((113.0, 79.0), -7), ((113.0, 78.0), -7), ((113.0, 77.0), -7), ((112.0, 74.0), -7), ((111.0, 73.0), -7), ((107.0, 88.0), -9), ((106.0, 88.0), -9), ((110.0, 87.0), -9), ((100.0, 69.0), -9), ((111.0, 86.0), -11), ((112.0, 85.0), -11), ((99.0, 84.0), -11), ((98.0, 81.0), -11), ((112.0, 75.0), -11), ((107.0, 72.0), -11), ((104.0, 71.0), -11), ((101.0, 69.0), -11), ((109.0, 87.0), -13), ((101.0, 87.0), -13), ((100.0, 86.0), -13), ((112.0, 84.0), -13), ((99.0, 83.0), -13), ((98.0, 80.0), -13), ((98.0, 78.0), -13), ((112.0, 76.0), -13), ((110.0, 73.0), -13), ((99.0, 73.0), -13), ((106.0, 72.0), -13), ((102.0, 70.0), -13), ((100.0, 70.0), -13), ((108.0, 87.0), -15), ((105.0, 87.0), -15), ((104.0, 87.0), -15), ((103.0, 87.0), -15), ((102.0, 87.0), -15), ((112.0, 83.0), -15), ((112.0, 82.0), -15), ((112.0, 81.0), -15), ((112.0, 80.0), -15), ((112.0, 79.0), -15), ((98.0, 79.0), -15), ((112.0, 78.0), -15), ((112.0, 77.0), -15), ((99.0, 75.0), -15), ((111.0, 74.0), -15), ((99.0, 74.0), -15), ((109.0, 73.0), -15), ((103.0, 71.0), -15), ((107.0, 87.0), -17), ((106.0, 87.0), -17), ((110.0, 86.0), -17), ((100.0, 85.0), -17), ((99.0, 82.0), -17), ((99.0, 76.0), -17), ((108.0, 73.0), -17), ((105.0, 72.0), -17), ((100.0, 71.0), -17), ((101.0, 70.0), -17), ((109.0, 86.0), -19), ((111.0, 85.0), -19), ((100.0, 84.0), -19), ((99.0, 81.0), -19), ((99.0, 77.0), -19), ((111.0, 75.0), -19), ((107.0, 73.0), -19), ((104.0, 72.0), -19), ((100.0, 72.0), -19), ((102.0, 71.0), -19), ((108.0, 86.0), -21), ((101.0, 86.0), -21), ((111.0, 84.0), -21), ((100.0, 83.0), -21), ((99.0, 80.0), -21), ((99.0, 78.0), -21), ((111.0, 76.0), -21), ((110.0, 74.0), -21), ((106.0, 73.0), -21), ((100.0, 73.0), -21), ((103.0, 72.0), -21), ((101.0, 71.0), -21), ((107.0, 86.0), -23), ((106.0, 86.0), -23), ((105.0, 86.0), -23), ((104.0, 86.0), -23), ((103.0, 86.0), -23), ((102.0, 86.0), -23), ((110.0, 85.0), -23), ((109.0, 85.0), -23), ((108.0, 85.0), -23), ((107.0, 85.0), -23), ((106.0, 85.0), -23), ((105.0, 85.0), -23), ((104.0, 85.0), -23), ((103.0, 85.0), -23), ((102.0, 85.0), -23), ((101.0, 85.0), -23), ((110.0, 84.0), -23), ((109.0, 84.0), -23), ((108.0, 84.0), -23), ((107.0, 84.0), -23), ((106.0, 84.0), -23), ((105.0, 84.0), -23), ((104.0, 84.0), -23), ((103.0, 84.0), -23), ((102.0, 84.0), -23), ((101.0, 84.0), -23), ((111.0, 83.0), -23), ((110.0, 83.0), -23), ((109.0, 83.0), -23), ((108.0, 83.0), -23), ((107.0, 83.0), -23), ((106.0, 83.0), -23), ((105.0, 83.0), -23), ((104.0, 83.0), -23), ((103.0, 83.0), -23), ((102.0, 83.0), -23), ((101.0, 83.0), -23), ((111.0, 82.0), -23), ((110.0, 82.0), -23), ((109.0, 82.0), -23), ((108.0, 82.0), -23), ((107.0, 82.0), -23), ((106.0, 82.0), -23), ((105.0, 82.0), -23), ((104.0, 82.0), -23), ((103.0, 82.0), -23), ((102.0, 82.0), -23), ((101.0, 82.0), -23), ((100.0, 82.0), -23), ((111.0, 81.0), -23), ((110.0, 81.0), -23), ((109.0, 81.0), -23), ((108.0, 81.0), -23), ((107.0, 81.0), -23), ((106.0, 81.0), -23), ((105.0, 81.0), -23), ((104.0, 81.0), -23), ((103.0, 81.0), -23), ((102.0, 81.0), -23), ((101.0, 81.0), -23), ((100.0, 81.0), -23), ((111.0, 80.0), -23), ((110.0, 80.0), -23), ((109.0, 80.0), -23), ((108.0, 80.0), -23), ((107.0, 80.0), -23), ((106.0, 80.0), - ...
# delta -1
# delta -1
# delta -1
# delta 3
# delta -15
# delta -9
# delta -3
# delta -7
# delta 3
# delta -13
# delta -5
# delta 3
# delta -3
# delta -3
# delta -1
# delta 1
# delta -1
# delta -1
# delta -1
# delta 3
# delta 3
# delta 3
# delta -13
# delta -9
# delta -5
# delta -5
# delta 3
# delta -7
# delta -13
# delta -15
# delta -1
# delta -7
# delta 5
# delta -13
# delta -5
# delta 1
# delta -13
# delta -5
# delta 3
# delta -1
# delta -1
# delta 3
# delta 1
# delta -11
# delta -3
# delta 5
# delta -1
# delta -1
# delta 5
# delta 1
# delta -1
# delta -1
# delta -1
# delta 3
# delta -3
# delta -3
# delta 3
# delta -1
# delta -1
# delta -1
# delta 3
# delta 1
# delta 3
# delta 5
# delta 7
# delta -13
# delta -11
# delta -7
# delta -5
# delta 1
# delta -15
# delta -15
# delta -13
# delta -7
# delta -5
# delta 1
# delta -13
# delta -13
# delta -13
# delta -5
# delta -5
# delta 3
# delta -11
# delta -11
# delta -11
# delta -3
# delta -3
# delta 5
# delta -9
# delta -9
# delta -9
# delta -1
# delta -1
# delta 7
# delta -3
# delta -9
# delta -15
# delta 1
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -11
# delta -3
# delta 5
# delta -9
# delta -1
# delta 7
# delta -7
# delta -1
# delta 5
# delta -3
# delta 1
# delta -11
# delta -11
# delta -9
# delta -3
# delta -1
# delta 5
# delta -9
# delta -9
# delta -9
# delta -1
# delta -1
# delta 7
# delta -13
# delta -9
# delta -3
# delta -5
# delta 3
# delta 1
# delta -15
# delta -7
# delta -1
# delta -7
# delta 3
# delta -11
# delta -3
# delta 3
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -9
# delta -1
# delta 5
# delta -5
# delta -3
# delta -1
# delta -13
# delta -9
# delta -21
# delta -19
# delta -17
# grid_x,grid_y 5 105 70
# delta -17
# grid 5 delta -17
# delta -1
# delta 3
# delta -7
# delta -3
# delta 1
# delta 1
# delta -13
# delta -9
# delta -3
# delta -5
# delta 3
# delta -7
# delta -13
# delta -15
# delta -1
# delta -7
# delta 5
# delta -3
# delta -11
# delta -19
# delta 1
# delta -13
# delta -5
# delta 3
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -3
# delta -11
# delta -19
# delta -3
# delta -19
# delta -3
# delta -11
# delta -19
# grid_x,grid_y 5 96 76
# delta -15
# grid 5 delta -15
# delta 9
# delta -11
# delta -3
# delta 5
# delta -5
# delta -1
# delta 3
# delta -3
# delta -11
# delta -19
# delta -5
# delta -21
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 97 71
# delta -19
# grid 5 delta -19
# delta 11
# delta -5
# delta -3
# delta -1
# delta -13
# delta -9
# delta -21
# delta -19
# delta -17
# grid_x,grid_y 5 104 70
# delta -17
# grid 5 delta -17
# delta -3
# delta 3
# delta -5
# delta -1
# delta 3
# delta 1
# delta -13
# delta -11
# delta -7
# delta -5
# delta 1
# delta -15
# delta -15
# delta -13
# delta -7
# delta -5
# delta 1
# delta -13
# delta -13
# delta -13
# delta -5
# delta -5
# delta 3
# delta -11
# delta -11
# delta -11
# delta -3
# delta -3
# delta 5
# delta -7
# delta -9
# delta -9
# delta 1
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -13
# delta -5
# delta 3
# delta -1
# delta -9
# delta -17
# delta -1
# delta -17
# delta -1
# delta -9
# delta -17
# grid_x,grid_y 5 96 77
# delta -13
# grid 5 delta -13
# delta 11
# delta -11
# delta -3
# delta 5
# delta -9
# delta -1
# delta 7
# delta -5
# delta -13
# delta -21
# delta -7
# delta -23
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 97 73
# delta -21
# grid 5 delta -21
# delta 7
# delta -5
# delta 1
# delta -1
# delta -9
# delta -17
# delta -3
# delta -19
# delta -5
# delta -13
# delta -21
# grid_x,grid_y 5 97 72
# delta -17
# grid 5 delta -17
# delta 13
# delta -5
# delta -1
# delta 3
# delta -7
# delta -3
# delta 1
# delta -11
# delta -11
# delta -9
# delta -3
# delta -1
# delta 5
# delta -9
# delta -9
# delta -9
# delta -1
# delta -1
# delta 7
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -5
# delta -13
# delta -21
# delta -1
# delta -13
# delta 3
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -3
# delta -11
# delta -19
# delta -5
# delta -21
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 97 74
# delta -19
# grid 5 delta -19
# delta 9
# delta -5
# delta -3
# delta 1
# delta -5
# delta -3
# delta 1
# delta -1
# delta -5
# delta -7
# delta -5
# delta -15
# delta -7
# delta -15
# delta -21
# grid_x,grid_y 5 98 69
# delta -7
# grid 5 delta -7
# delta 15
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -9
# delta -3
# delta 3
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -3
# delta -11
# delta -19
# delta -5
# delta -21
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 97 75
# delta -19
# grid 5 delta -19
# delta 9
# delta -7
# delta -1
# delta 5
# delta -5
# delta -3
# delta -1
# delta -13
# delta -9
# delta -21
# delta -19
# delta -17
# grid_x,grid_y 5 105 71
# delta -17
# grid 5 delta -17
# delta -1
# delta 3
# delta -7
# delta -3
# delta 1
# delta -1
# delta -7
# delta -11
# delta -5
# delta -19
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 98 70
# delta -11
# grid 5 delta -11
# delta 15
# delta -1
# delta -1
# delta 3
# delta -13
# delta -11
# delta -7
# delta -5
# delta 1
# delta -3
# delta -9
# delta -15
# delta 1
# delta -13
# delta -5
# delta 3
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -5
# delta -13
# delta -21
# delta -3
# delta -19
# delta 1
# delta -3
# delta -11
# delta -19
# delta -3
# delta -19
# delta -3
# delta -11
# delta -19
# grid_x,grid_y 5 97 76
# delta -15
# grid 5 delta -15
# delta 9
# delta -11
# delta -3
# delta 5
# delta -3
# delta 1
# delta -5
# delta -3
# delta -1
# delta -13
# delta -9
# delta -21
# delta -19
# delta -17
# grid_x,grid_y 5 104 71
# delta -17
# grid 5 delta -17
# delta -1
# delta 3
# delta -3
# delta -9
# delta -15
# delta -5
# delta -21
# delta -7
# delta -15
# delta -23
# grid_x,grid_y 5 98 71
# delta -15
# grid 5 delta -15
# delta 13
# delta -7
# delta -3
# delta 1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -11
# delta -11
# delta -9
# delta -3
# delta -1
# delta 5
# delta -5
# delta -9
# delta -9
# delta 1
# delta -11
# delta -5
# delta 1
# delta -13
# delta -9
# delta -3
# delta -5
# delta 3
# delta -13
# delta -11
# delta -7
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -7
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -1
# delta -5
# delta -9
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -9
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -3
# delta -7
# delta -9
# delta 3
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -11
# delta -11
# delta -9
# delta -3
# delta -1
# delta 5
# delta -5
# delta -9
# delta -9
# delta 1
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -7
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -1
# delta -5
# delta -9
# delta 3
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -9
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -3
# delta -7
# delta -9
# delta 3
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -9
# delta -11
# delta -9
# delta -3
# delta -1
# delta 5
# delta -3
# delta -7
# delta -9
# delta 1
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -9
# delta -11
# delta -9
# delta -3
# delta -1
# delta 3
# delta -3
# delta -7
# delta -9
# delta 1
# delta 3
# delta -7
# delta -1
# delta 5
# delta -11
# delta -5
# delta 1
# delta -13
# delta -9
# delta -3
# delta -5
# delta 1
# delta -13
# delta -11
# delta -7
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -7
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -1
# delta -5
# delta -9
# delta 3
# delta -5
# delta 1
# delta -9
# delta -3
# delta 3
# delta -13
# delta -7
# delta -1
# delta -5
# delta 3
# delta -13
# delta -11
# delta -5
# delta -5
# delta 1
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -7
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -1
# delta -5
# delta -9
# delta 3
# delta -7
# delta -1
# delta 5
# delta -11
# delta -5
# delta 1
# delta -13
# delta -9
# delta -3
# delta -5
# delta 1
# delta -13
# delta -11
# delta -7
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -7
# delta -11
# delta -9
# delta -1
# delta -1
# delta 5
# delta -1
# delta -5
# delta -9
# delta 3
# delta -1
# delta 3
# delta -3
# delta 1
# delta -5
# delta -1
# delta 3
# delta -7
# delta -3
# delta 1
# delta -9
# delta -5
# delta -1
# delta -5
# delta -1
# delta 3
# delta -11
# delta -7
# delta -3
# delta -5
# delta -1
# delta 3
# delta -13
# delta -9
# delta -5
# delta -5
# delta -1
# delta 3
# delta -13
# delta -11
# delta -7
# delta -5
# delta -1
# delta 3
# delta -11
# delta -11
# delta -9
# delta -5
# delta -1
# delta 3
# delta -5
# delta -9
# delta -9
# delta -1
# delta -1
# delta 5
# delta 1
# delta 3
# delta 3
# delta 1
# delta -1
# delta 3
# delta -3
# delta 1
# delta -7
# delta -1
# delta 3
# delta -9
# delta -5
# delta 1
# delta -7
# delta -7
# delta -3
# delta -3
# delta -1
# delta 3
# delta -3
# delta -5
# delta -5
# delta 1
# delta 3
# delta 3
# delta 1
# delta -1
# delta 3
# delta 1
# delta 3
# delta 5
# delta 7
# ..............length.......... 0

# %%
import cv2
dir_ = "/media/rtb7syl/New Volume/books/vortex_data/vortex/vortex/4ch/intra-subject/scan_1/phase_1/x/registered-resized-1/png/27.png"
x = cv2.imread(dir_)
img = cv2.imread('xxxpq1.png')
img1 = cv2.imread('xxxpq6.png')
#img = cv2.medianBlur(img,5)

img1 = cv2.medianBlur(img1,11)

#cv2.imshow('xxxpq1',img)
cv2.imshow('xxxpq5',img1)
cv2.imshow('dir',x)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import os 

dir_ = "./imgs/wrap_detected7"
fname = os.path.join(dir_,'37.jpg')
print(fname)
hsv = cv2.imread(fname)
print(hsv.shape)
cv2.imshow('img2_hsv',hsv)
cv2.waitKey(0)
# Out:
# ./imgs/wrap_detected7/37.jpg
# (192, 384, 3)

# %%
import os

dir_ = "./gray_frames"
fname = os.path.join(dir_,'36.jpg')
print(fname)
hsv = cv2.imread(fname)
print(hsv.shape)
hsv=cv2.cvtColor(hsv, cv2.COLOR_BGR2GRAY)
print(hsv.shape)
cv2.imshow('img2_hsv',hsv)
cv2.waitKey(0)


import glob

#print(glob.glob("./processed/processed/phase_data_la4ch1/png_frames/*.png"))
hsv_images = [cv2.imread(file) for file in glob.glob("./hsv_frames/*.jpg")]
print(len(hsv_images))

'''
img2.shape
img2_rgb=cv2.cvtColor(img2, cv2.COLOR_HSV2RGB)
'''
'''
cv2.imshow('img2_rgb',img)
cv2.imshow('img2_hsv',hsv)
cv2.waitKey(0)
'''
# Out:
# ./gray_frames/36.jpg
# (192, 192, 3)
# (192, 192)

# %%
# lower mask (0-10)
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)

# upper mask (170-180)
lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)

# join my masks
mask = mask0+mask1

# set my output img to zero everywhere except my mask
output_img = img.copy()
output_img[np.where(mask==0)] = 0

# or your HSV image, which I *believe* is what you want
output_hsv = img_hsv.copy()
output_hsv[np.where(mask==0)] = 0

cv2.imshow('img',output_img )
cv2.imshow('img_hsv',output_hsv)
cv2.waitKey(0)

# %%
mask1 = cv2.inRange(hsv, (0,50,50), (10,255,255))
mask2 = cv2.inRange(hsv, (170,50,50), (180,255,255))

mask = cv2.bitwise_or(mask1, mask2)
#dst  = cv2.bitwise_and(img, img, mask=mask)
dst_hsv = cv2.bitwise_and(hsv, hsv, mask=mask)

cv2.imshow('img_hsv',dst_hsv)
cv2.waitKey(0)

ret,thresh = cv2.threshold(mask, 40, 255, 0)
im2,contours,hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

if len(contours) != 0:
    # draw in blue the contours that were founded
    #cv2.drawContours(dst, contours, -1, 255, 5)
    #cv2.drawContours(dst_hsv.copy(), contours, -1, 255, 5)

    #find the biggest area
    c = max(contours, key = cv2.contourArea)

    x,y,w,h = cv2.boundingRect(c)
    print(w,h)
    # draw the book contour (in green)
    #cv2.rectangle(dst,(x,y),(x+w,y+h),(0,0,255),3)
    cv2.rectangle(hsv,(x,y),(x+w,y+h),(0,0,255),2)
    cv2.rectangle(rgb,(x,y),(x+w,y+h),(0,0,255),2)
    #cv2.rectangle(img1,(x,y),(x+w,y+h),(0,0,255),2)
    
    '''
    (x, y), radius = cv2.minEnclosingCircle(c)
    # convert all values to int
    center = (int(x), int(y))
    radius = int(radius)
    # and draw the circle in blue
    cv2.circle(dst_hsv, center, radius, (255, 0, 0), 2)
    '''

# show the images
cv2.imshow("Result", np.hstack([hsv,rgb]))
#cv2.imshow('vv',img1)
cv2.waitKey(0)
 
#cv2.imshow('img',dst )
#cv2.imshow('img_hsv',dst_hsv)
cv2.waitKey(0)
# Out:
# 15 17

# %%
import os
def identify_phasewrap(hsv):
    
    # takes in a single img in hsv format
    
    # returns x,y,w,h of the rect bbox around phase-wrap ROI
    
    mask1 = cv2.inRange(hsv, (0,50,50), (10,255,255))
    mask2 = cv2.inRange(hsv, (170,50,50), (180,255,255))

    mask = cv2.bitwise_or(mask1, mask2)
    #dst  = cv2.bitwise_and(img, img, mask=mask)
    dst_hsv = cv2.bitwise_and(hsv, hsv, mask=mask)

    #cv2.imshow('img_hsv',dst_hsv)
    #cv2.waitKey(0)

    ret,thresh = cv2.threshold(mask, 40, 255, 0)
    im2,contours,hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    if len(contours) != 0:

        c = max(contours, key = cv2.contourArea)

        x,y,w,h = cv2.boundingRect(c)
        
        print(w,h) 
        
        return (x,y,w,h)
    
def draw_bbox(img,x,y,w,h):
    
    # draw rect bbox of dimensions defined by x,y,w,h in the img
    # and returns the img
    
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)
    
    return img
    

def main():
    
    hsv_dir = './hsv_frames'
    gray_dir = './gray_frames'
    
    for fname in os.listdir(hsv_dir):
        
         
        
        hsv = cv2.imread(hsv_dir + '/'+ fname)
        
        if hsv is None:
            
            raise RuntimeError
        
        #hsv = hsv1.copy()
        
        rgb= cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
        
        gray= cv2.imread(gray_dir + '/'+ fname)
        
        x,y,w,h = identify_phasewrap(hsv)
        
        
        print(fname + ' w = '+ str(w) + ' h = ' + str(h))
        
        if (w*h >= 500):
        
            hsv_img = draw_bbox(hsv,x,y,w,h)

            rgb_img = draw_bbox(rgb,x,y,w,h)
            
            gray_img = draw_bbox(gray,x,y,w,h)


            bboxed_imgs = np.hstack([gray_img,hsv_img,rgb_img])
            
        else:
            
            bboxed_imgs = np.hstack([gray,hsv,rgb])
        
        cv2.imwrite('./wrap_detected5/'+fname,bboxed_imgs)
            
        
#main()

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

import os

def identify_phasewrap_gray(gray):
    
    # takes in a single img in hsv format
    
    # returns x,y,w,h of the rect bbox around phase-wrap ROI
    
    mask1 = cv2.inRange(gray, 10, 30)
    mask2 = cv2.inRange(gray, 30, 35)

    mask = cv2.bitwise_or(mask1, mask2)
    #dst  = cv2.bitwise_and(img, img, mask=mask)
    #dst_gray = cv2.bitwise_and(gray, gray, mask=mask)

    #cv2.imshow('img_seg_gray',dst_gray)
    #cv2.imshow('img_mask',mask)
    #cv2.waitKey(0)

    ret,thresh = cv2.threshold(mask, 40, 255, 0)
    #cv2.imshow('img_seg_gray',thresh)
    #cv2.waitKey(0)
    #thresh.astype('uint8')
    im2,contours,hierarchy = cv2.findContours(thresh, cv2.RETR_+LIST, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) != 0:

        c = max(contours, key = cv2.contourArea)

        x,y,w,h = cv2.boundingRect(c)
        
        
        print(x,y,w,h) 
        
        return (x,y,w,h)

    
def draw_bbox(img,x,y,w,h):
    
    # draw rect bbox of dimensions defined by x,y,w,h in the img
    # and returns the img
    
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)
    
    return img


def capture_white_pixels(img,x,y,w,h):
    
    # capturs the white pixels from the cropped region and returns them
    
    # cropped region of image defined by x,y,w,h
    crop_img = img[y:y+h, x:x+w]
    
    crop_img[crop_img > 230] = 0
    
    
    
def main1(): 
    


    gray_dir = './gray_frames'
    
    for fname in os.listdir(gray_dir):
        
         
        
        gray_img = cv2.imread(gray_dir + '/'+ fname)
        
        if gray_img is None:
            
            raise RuntimeError
            
        gray_img=cv2.cvtColor(gray_img, cv2.COLOR_BGR2GRAY)
        
        gray = gray_img.copy()
        
        
        #rgb= cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
        
        #gray= cv2.imread(gray_dir + '/'+ fname)
        
        x,y,w,h = identify_phasewrap_gray(gray)
        
        
        print(fname + ' w = '+ str(w) + ' h = ' + str(h))
        
        if (w*h >= 400):
        
            #hsv_img = draw_bbox(hsv,x,y,w,h)

            #rgb_img = draw_bbox(rgb,x,y,w,h)
            
            gray_boxed = draw_bbox(gray,x,y,w,h)


            bboxed_imgs = np.hstack([gray_img,gray_boxed])
            
        else:
            
            bboxed_imgs = np.hstack([gray_img,gray_img])
        
        cv2.imwrite('./wrap_detected7/'+fname,bboxed_imgs)

    
main1()
# Out:
# 78 187 2 4
# 28.jpg w = 2 h = 4
# 144 86 3 3
# 47.jpg w = 3 h = 3
# 145 64 2 2
# 1.jpg w = 2 h = 2
# 127 133 3 3
# 10.jpg w = 3 h = 3
# 136 74 4 4
# 11.jpg w = 4 h = 4
# 92 14 3 3
# 12.jpg w = 3 h = 3
# 133 128 3 2
# 13.jpg w = 3 h = 2
# 146 105 2 2
# 14.jpg w = 2 h = 2
# 145 104 4 5
# 15.jpg w = 4 h = 5
# 153 171 2 2
# 16.jpg w = 2 h = 2
# 151 80 4 3
# 17.jpg w = 4 h = 3
# 151 78 4 4
# 18.jpg w = 4 h = 4
# 148 65 3 5
# 19.jpg w = 3 h = 5
# 141 114 2 2
# 2.jpg w = 2 h = 2
# 165 161 2 3
# 20.jpg w = 2 h = 3
# 153 99 3 2
# 21.jpg w = 3 h = 2
# 130 128 3 3
# 22.jpg w = 3 h = 3
# 131 80 3 2
# 23.jpg w = 3 h = 2
# 151 95 3 2
# 24.jpg w = 3 h = 2
# 145 98 3 4
# 25.jpg w = 3 h = 4
# 165 168 3 3
# 26.jpg w = 3 h = 3
# 136 100 2 4
# 27.jpg w = 2 h = 4
# 133 93 4 4
# 29.jpg w = 4 h = 4
# 137 115 2 2
# 3.jpg w = 2 h = 2
# 149 103 2 2
# 30.jpg w = 2 h = 2
# 132 77 3 3
# 31.jpg w = 3 h = 3
# 142 98 3 2
# 32.jpg w = 3 h = 2
# 70 35 7 4
# 33.jpg w = 7 h = 4
# 93 21 3 3
# 34.jpg w = 3 h = 3
# 98 70 19 14
# 35.jpg w = 19 h = 14
# 97 67 21 21
# 36.jpg w = 21 h = 21
# 96 64 22 27
# 37.jpg w = 22 h = 27
# 96 64 21 30
# 38.jpg w = 21 h = 30
# 96 63 20 31
# 39.jpg w = 20 h = 31
# 156 50 2 3
# 4.jpg w = 2 h = 3
# 96 63 19 31
# 40.jpg w = 19 h = 31
# 97 65 18 27
# 41.jpg w = 18 h = 27
# 101 70 13 20
# 42.jpg w = 13 h = 20
# 103 78 10 11
# 43.jpg w = 10 h = 11
# 106 81 3 5
# 44.jpg w = 3 h = 5
# 157 78 5 5
# 45.jpg w = 5 h = 5
# 148 122 3 3
# 46.jpg w = 3 h = 3
# 153 49 2 2
# 48.jpg w = 2 h = 2
# 153 47 5 4
# 49.jpg w = 5 h = 4
# 137 115 4 3
# 5.jpg w = 4 h = 3
# 32 28 3 2
# 50.jpg w = 3 h = 2
# 156 102 4 5
# 51.jpg w = 4 h = 5
# 132 180 2 2
# 52.jpg w = 2 h = 2
# 66 189 2 3
# 53.jpg w = 2 h = 3
# 54 183 3 3
# 54.jpg w = 3 h = 3
# 146 74 3 3
# 55.jpg w = 3 h = 3
# 153 179 2 2
# 56.jpg w = 2 h = 2
# 147 113 3 3
# 57.jpg w = 3 h = 3
# 149 115 5 4
# 58.jpg w = 5 h = 4
# 154 91 3 4
# 59.jpg w = 3 h = 4
# 147 52 4 2
# 6.jpg w = 4 h = 2
# 137 91 4 5
# 60.jpg w = 4 h = 5
# 142 95 4 2
# 61.jpg w = 4 h = 2
# 95 26 3 5
# 62.jpg w = 3 h = 5
# 158 75 2 3
# 63.jpg w = 2 h = 3
# 159 181 3 2
# 64.jpg w = 3 h = 2
# 155 65 4 3
# 65.jpg w = 4 h = 3
# 154 92 2 3
# 66.jpg w = 2 h = 3
# 146 119 3 2
# 67.jpg w = 3 h = 2
# 162 161 2 3
# 68.jpg w = 2 h = 3
# 149 46 2 2
# 69.jpg w = 2 h = 2
# 159 184 2 2
# 7.jpg w = 2 h = 2
# 147 173 3 3
# 70.jpg w = 3 h = 3
# 163 166 2 2
# 71.jpg w = 2 h = 2
# 158 162 2 2
# 72.jpg w = 2 h = 2
# 157 107 3 3
# 73.jpg w = 3 h = 3
# 140 129 2 3
# 74.jpg w = 2 h = 3
# 143 75 3 3
# 75.jpg w = 3 h = 3
# 135 110 2 2
# 8.jpg w = 2 h = 2
# 157 69 2 3
# 9.jpg w = 2 h = 3

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

import os

def identify_phasewrap_gray(gray):
    
    # takes in a single img in hsv format
    
    # returns x,y,w,h of the rect bbox around phase-wrap ROI
    
    mask1 = cv2.inRange(gray, 10, 30)
    mask2 = cv2.inRange(gray, 30, 35)

    mask = cv2.bitwise_or(mask1, mask2)


    ret,thresh = cv2.threshold(mask, 40, 255, 0)

    im2,contours,hierarchy = cv2.findContours(thresh, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) != 0:

        c = max(contours, key = cv2.contourArea)

        x,y,w,h = cv2.boundingRect(c)
        
        
        print(x,y,w,h) 
        
        return (x,y,w,h)

    
def draw_bbox(img,x,y,w,h):
    
    # draw rect bbox of dimensions defined by x,y,w,h in the img
    # and returns the img
    
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,255),2)
    
    return img


def capture_white_pixels(img,white_thresh,x,y,w,h):
    
    # captures the white pixels in the cropped region
    # and returns them with relative to the cropped region
    # white_thresh is the min white pixel intensity 
    
    
    
    # cropped region of image defined by x,y,w,h
    crop_img = img[y:y+h, x:x+w]
    
    num_of_white_pixels = len(crop_img[crop_img >= white_thresh])
    
    print('num_of_white_pixels = ', str(num_of_white_pixels))
    
    print('white pixel coordinates\n')
    
    indices = np.nonzero(crop_img >= white_thresh)
    
    print(indices)
    y_indices = indices[0]
    x_indices = indices[1]
    
    # array of white px coordinates with respect to the cropped sq.
    white_pixel_coordinates = np.column_stack((x_indices,y_indices)) 
    
    print(white_pixel_coordinates)
    
    return (white_pixel_coordinates,num_of_white_pixels)


'''
def scale_each_coordinate(white_pixel_coordinate,x,y):
    
    #scaled_coordinate = np.array([white_pixel_coordinate[0] + x,white_pixel_coordinate[1] + y]) 
    print(white_pixel_coordinate)
    return white_pixel_coordinate
'''    
    
def scale_pixel_coordinates(white_pixel_coordinates,x,y):
    
    # returns final scaled coordinates array wrt to the entire image
    
    
    scale_each_coordinate = lambda white_pixel_coordinate : np.array([white_pixel_coordinate[0] + x,white_pixel_coordinate[1] + y])
    white_pixel_coordinates = np.array(list(map(scale_each_coordinate,white_pixel_coordinates)))
    
    #white_pixel_coordinates = vscale_each_coordinate(white_pixel_coordinates,x,y)
    
    return white_pixel_coordinates



def save_white_pixel_coordinates_as_csv(csv_fname,white_pixel_coordinates):
    
    # saves the numpy 2D pixel coordinates as a csv 
    
    np.savetxt(csv_fname,white_pixel_coordinates,fmt='%.2e',delimiter=',')
    
    
    

    

    
def load_image_and_get_roi(dir_,fname):
    
    # loads image and returns the img numpy array coordinates of the roi

    img = cv2.imread(dir_ + '/'+ fname)

    if img is None:

        raise RuntimeError

    img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    gray = img.copy()

    #rgb= cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

    #gray= cv2.imread(gray_dir + '/'+ fname)

    x,y,w,h = identify_phasewrap_gray(gray)

    return (img,x,y,w,h)
    


def check_img_for_wrap_and_write_coords_to_csv(dir_,img_fname,out_fname,sq_area_thresh,white_thresh):
    
    '''
    dir_ = './gray_frames'
    fname = '41.jpg'
    sq_area_thresh = 400
    '''
    
    img,x,y,w,h = load_image_and_get_roi(dir_,img_fname)
    
    if (w * h) >= sq_area_thresh:
        
        white_pixel_coordinates,num_of_white_pixels = capture_white_pixels(img,white_thresh,x,y,w,h)
        
        if (num_of_white_pixels > 0):

            white_pixel_coordinates = scale_pixel_coordinates(white_pixel_coordinates,x,y)
            
            print('white pixel coordinates\n')

            print(white_pixel_coordinates)

            save_white_pixel_coordinates_as_csv(out_fname,white_pixel_coordinates)


def correct_phase_wrap(img,fname,x,y,w,h):

    # cropped region of image defined by x,y,w,h
    
    gray = img.copy()
    
    crop_img = img[y:y+h, x:x+w]
    
    out_img = cv2.medianBlur(crop_img, 7)
    
    img[y:y+h, x:x+w] = out_img
    
    #imgs = np.hstack([gray,img])
        
    cv2.imwrite('./wrap_corrected/'+'corrected_'+fname,img)
    print('done')
    
    #cv2.imshow('v',imgs)
    
    #cv2.imshow('vv',crop_img)
    #cv2.imshow('vv1',out_img)
    #cv2.waitKey(0)
    
    
def main():
    
    dir_ = './gray_frames'
    
    fname = '40.jpg'
    
    '''
    for fname in os.listdir(dir_):
        
        out_fname = fname.split('.')[0] + '.csv'
        
        sq_area_thresh = 400
        
        white_thresh = 210
        
        check_img_for_wrap_and_write_coords_to_csv(dir_,fname,out_fname,sq_area_thresh,white_thresh)
        
    '''
    
    img,x,y,w,h = load_image_and_get_roi(dir_,fname)
    correct_phase_wrap(img,fname,x,y,w,h)
     
        
        
        
        
#load_image_and_get_roi('./gray_frames','38.jpg')       
main()
# Out:
# 96 63 19 31
# done

# %%
# !pwd
# Out:
# /home/rtb7syl/Projects/phase-unwrap

# %%
# !python utils.py
# Out:
# [[98.0, 72.0], [99.0, 72.0], [113.0, 72.0], [102.0, 74.0], [113.0, 75.0], [99.0, 76.0], [100.0, 76.0], [100.0, 77.0], [101.0, 77.0], [113.0, 77.0], [115.0, 80.0], [104.0, 81.0], [106.0, 81.0]]
# 97 67 21 21
# grid_x,grid_y 9 14
# [  1   2   4   5   6   7   7   8   9  12  13  13  14  14  14  14  14  15
#   16  16  16  16  17  17  18  18  18  19  19  20  20  20  22  22  23  23
#   23  27  28  28  30  30  32  33  33  36  37 241 245]
# 46 37
# WC pixel val before =  (12, 17) 245
# WC pixel val after =  37
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2
# XmbTextListToTextProperty result code -2

# %%
# !python unwrap.py
# Out:
# 96 63 19 31
# [[102.0, 75.0], [100.0, 78.0], [112.0, 80.0], [100.0, 81.0], [101.0, 81.0], [101.0, 82.0], [101.0, 83.0]]
# [[9.0, 15.0], [7.0, 18.0], [19.0, 20.0], [7.0, 21.0], [8.0, 21.0], [8.0, 22.0], [8.0, 23.0]]
# wrapped_coords [[9.0, 15.0], [7.0, 18.0], [19.0, 20.0], [7.0, 21.0], [8.0, 21.0], [8.0, 22.0], [8.0, 23.0]]
# grid_x,grid_y 8.0 14.0
# delta 7
# grid_x,grid_y 6.0 17.0
# delta 7
# grid_x,grid_y 18.0 19.0
# delta 7
# grid_x,grid_y 6.0 20.0
# delta 1
# grid_x,grid_y 7.0 20.0
# delta 1
# grid_x,grid_y 7.0 21.0
# delta 1
# grid_x,grid_y 7.0 22.0
# delta 5
# [((19.0, 20.0), 7), ((7.0, 18.0), 7), ((9.0, 15.0), 7), ((8.0, 23.0), 5), ((8.0, 22.0), 1), ((8.0, 21.0), 1), ((7.0, 21.0), 1)]
# median 10.0
# WC pixel val before =  (19, 20) 10
# WC pixel val after =  10
# median 10.0
# WC pixel val before =  (7, 18) 47
# WC pixel val after =  10
# median 23.0
# WC pixel val before =  (9, 15) 24
# WC pixel val after =  23
# median 21.0
# WC pixel val before =  (8, 23) 0
# WC pixel val after =  21
# median 21.0
# WC pixel val before =  (8, 22) 0
# WC pixel val after =  21
# median 15.0
# WC pixel val before =  (8, 21) 87
# WC pixel val after =  15
# median 21.0
# WC pixel val before =  (7, 21) 89
# WC pixel val after =  21
# done
